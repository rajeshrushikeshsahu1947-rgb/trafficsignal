# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BOYtFyd3Dzs1sMv5Dj0g")
project = rf.workspace("computervision-5gyzq").project("cinta_v2-5sjvx")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/38.8 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.6/38.8 MB 2.9 MB/s eta 0:00:13
#    -- ------------------------------------- 2.1/38.8 MB 2.8 MB/s eta 0:00:14
#    -- ------------------------------------- 2.6/38.8 MB 2.6 MB/s eta 0:00:14
#    -- ------------------------------------- 2.9/38.8 MB 2.5 MB/s eta 0:00:15
#    --- ------------------------------------ 3.4/38.8 MB 2.5 MB/s eta 0:00:15
#    ---- ----------------------------------- 3.9/38.8 MB 2.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.2/38.8 MB 2.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.7/38.8 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.2/38.8 MB 2.4 MB/s eta 0:00:15
# ...

# %%
# Install YOLOv8
# !pip install ultralytics

from ultralytics import YOLO

# Load a pretrained YOLOv8 model (nano version is fastest to start)
model = YOLO("yolov8n.pt")

# Train on your dataset
model.train(
    data="data.yaml",   # path to your corrected yaml
    epochs=50,          # number of training epochs
    imgsz=640           # image size
)
# Out:
# ...
# Ultralytics 8.4.33  Python-3.9.25 torch-2.8.0+cpu CPU (Intel Core 7 240H)
# ...
